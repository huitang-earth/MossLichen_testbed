# %% [markdown]
# # FATES output plotting

# %%
import xarray as xr
from matplotlib.pylab import plt
xr.set_options(display_style="html")
# %matplotlib inline

# %%
ALP1_lichen = xr.open_dataset('~/saga/work/ctsm/ALP1_lichen/run/ALP1_lichen.clm2.h0.2000_test3.nc', decode_times=False)#alp1
ALP1_lichen1 = xr.open_dataset('~/saga/work/ctsm/ALP1_lichen/run/ALP1_lichen.clm2.h0.2000_tg_to_tv_resp_nofwet.nc', decode_times=False)#alp1
ALP1_lichen2 = xr.open_dataset('~/saga/work/ctsm/ALP1_lichen/run/ALP1_lichen.clm2.h0.2000_tg_to_tv_resp_10clump_0xl_nofwet.nc', decode_times=False)#alp1
ALP1_moss0 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_test3.nc', decode_times=False)#alp1
ALP1_moss1 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_tg_to_tv.nc', decode_times=False)#alp1
ALP1_moss2 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_tg_to_tv_resp_0tau_10clump_0xl_nofwet_snowburial_tsoil_qg.nc', decode_times=False)#alp1
#ALP1_moss3 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_tg_to_tv_resp_0tau_1clump_0xl.nc', decode_times=False)#alp1
ALP1_moss4 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_tg_to_tv_resp_0tau_10clump_0xl_nofwet_snowburial2.nc', decode_times=False)#alp1
ALP1_moss5 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_tg_to_tv_resp_0tau_1clump_0xl_nofwet.nc', decode_times=False)#alp1
ALP1_moss6 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_tg_to_tv_resp_0tau_10clump_0xl_nofwet.nc', decode_times=False)#alp1
ALP1_moss7 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_tg_to_tv_resp_0tau_10clump_0xl_nofwet_snowburial.nc', decode_times=False)#alp1
ALP1_moss8 = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h0.2000_tg_to_tv_resp_0tau_10clump_0xl_nofwet_snowburial_tsoil.nc', decode_times=False)#alp1

ALP1_grass_daily = xr.open_dataset('~/saga/work/ctsm/ALP1_grass/run/ALP1_grass.clm2.h2.2000_daily.nc', decode_times=False)#alp1
ALP1_lichen_daily = xr.open_dataset('~/saga/work/ctsm/ALP1_lichen/run/ALP1_lichen.clm2.h2.2000_daily.nc', decode_times=False)#alp1
ALP1_moss_daily = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h2.2000_daily.nc', decode_times=False)#alp1

# %%
plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['FSR']/ALP1_lichen['FSDS'],label='lichen_0.75clump')
#plt.plot(ALP1_lichen1['FSR']/ALP1_lichen1['FSDS'],label='lichen_0.75clump_nofwet')
#plt.plot(ALP1_lichen2['FSR']/ALP1_lichen2['FSDS'],label='lichen_10clump_nofwet')
#plt.plot(ALP1_moss0['FSR']/ALP1_moss0['FSDS'],label='moss')
plt.plot(ALP1_moss1['FSR']/ALP1_moss1['FSDS'],label='moss_ctrl')
plt.plot(ALP1_moss2['FSR']/ALP1_moss2['FSDS'],label='moss_0.01tau')
#plt.plot(ALP1_moss3['FSR']/ALP1_moss3['FSDS'],label='moss_test3')
plt.plot(ALP1_moss4['FSR']/ALP1_moss4['FSDS'],label='moss_0.01tau_1clump')
plt.plot(ALP1_moss8['FSR']/ALP1_moss8['FSDS'],label='moss_0.01tau_1clump_nofwet')
plt.plot(ALP1_moss6['FSR']/ALP1_moss6['FSDS'],label='moss_0.01tau_10clump_nofwet')
plt.plot(ALP1_moss7['FSR']/ALP1_moss6['FSDS'],label='moss_0.01tau_10clump_nofwet_snowburial')

plt.xlabel("time (months)")
plt.ylabel("Albedo")
plt.title("Monthly mean albedo")
plt.legend(loc=3)
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_albedo.png")
plt.show()

# %%
plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['SABG'],label='moss_test1')
plt.plot(ALP1_moss2['SABG'],label='moss_test2')
plt.plot(ALP1_moss4['SABG'],label='moss_test4')
plt.plot(ALP1_moss8['SABG'],label='moss_test5')
plt.plot(ALP1_moss6['SABG'],label='moss_test6')
plt.plot(ALP1_moss7['SABG'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("SABG (W/m^2)")
plt.title("solar rad absorbed by ground")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_SABG.png")
plt.show()

plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABV'],label='lichen')
#plt.plot(ALP1_lichen1['SABV'],label='lichen')
#plt.plot(ALP1_lichen2['SABV'],label='lichen')
plt.plot(ALP1_moss1['SABV'],label='moss_test1')
plt.plot(ALP1_moss2['SABV'],label='moss_test2')
plt.plot(ALP1_moss4['SABV'],label='moss_test4')
plt.plot(ALP1_moss8['SABV'],label='moss_test5')
plt.plot(ALP1_moss6['SABV'],label='moss_test6')
plt.plot(ALP1_moss7['SABV'],label='moss_test7')
plt.xlabel("time (months)")
plt.ylabel("SABV (W/m^2)")
plt.title("solar rad absorbed by vegetation")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_SABV.png")
plt.show()

# %%
plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['PARVEGLN'],label='moss_test1')
plt.plot(ALP1_moss2['PARVEGLN'],label='moss_test2')
plt.plot(ALP1_moss4['PARVEGLN'],label='moss_test4')
plt.plot(ALP1_moss8['PARVEGLN'],label='moss_test5')
plt.plot(ALP1_moss6['PARVEGLN'],label='moss_test6')
plt.plot(ALP1_moss7['PARVEGLN'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("PARVEGLN (W/m^2)")
plt.title("absorbed par by vegetation at local noon")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_PARVEGLN.png")
plt.show()

# %%
plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['GPP'],label='moss_test1')
plt.plot(ALP1_moss2['GPP'],label='moss_test2')
plt.plot(ALP1_moss4['GPP'],label='moss_test4')
plt.plot(ALP1_moss8['GPP'],label='moss_test5')
plt.plot(ALP1_moss6['GPP'],label='moss_test6')
plt.plot(ALP1_moss7['GPP'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("GPP (gC/m^2/s)")
plt.title("gross primary production")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_GPP.png")
plt.show()

plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['NPP'],label='moss_test1')
plt.plot(ALP1_moss2['NPP'],label='moss_test2')
plt.plot(ALP1_moss4['NPP'],label='moss_test4')
plt.plot(ALP1_moss8['NPP'],label='moss_test5')
plt.plot(ALP1_moss6['NPP'],label='moss_test6')
plt.plot(ALP1_moss7['NPP'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("NPP (gC/m^2/s)")
plt.title("net primary production")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_GPP.png")
plt.show()

plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['ELAI'],label='moss_test1')
plt.plot(ALP1_moss2['ELAI'],label='moss_test2')
plt.plot(ALP1_moss4['ELAI'],label='moss_test4')
plt.plot(ALP1_moss8['ELAI'],label='moss_test5')
plt.plot(ALP1_moss6['ELAI'],label='moss_test6')
plt.plot(ALP1_moss7['ELAI'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("NPP (gC/m^2/s)")
plt.title("net primary production")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_GPP.png")
plt.show()

plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['H2OSNO'],label='moss_test1')
plt.plot(ALP1_moss2['H2OSNO'],label='moss_test2')
plt.plot(ALP1_moss4['H2OSNO'],label='moss_test4')
plt.plot(ALP1_moss8['H2OSNO'],label='moss_test5')
plt.plot(ALP1_moss6['H2OSNO'],label='moss_test6')
plt.plot(ALP1_moss7['H2OSNO'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("NPP (gC/m^2/s)")
plt.title("net primary production")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_GPP.png")
plt.show()

plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['FSNO_EFF'],label='moss_test1')
plt.plot(ALP1_moss2['FSNO_EFF'],label='moss_test2')
plt.plot(ALP1_moss4['FSNO_EFF'],label='moss_test4')
plt.plot(ALP1_moss8['FSNO_EFF'],label='moss_test5')
plt.plot(ALP1_moss6['FSNO_EFF'],label='moss_test6')
plt.plot(ALP1_moss7['FSNO_EFF'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("NPP (gC/m^2/s)")
plt.title("net primary production")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_GPP.png")
plt.show()

plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['TV'],label='moss_test1')
plt.plot(ALP1_moss2['TV'],label='moss_test2')
plt.plot(ALP1_moss4['TV'],label='moss_test4')
plt.plot(ALP1_moss8['TV'],label='moss_test5')
plt.plot(ALP1_moss6['TV'],label='moss_test6')
plt.plot(ALP1_moss7['TV'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("NPP (gC/m^2/s)")
plt.title("net primary production")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_GPP.png")
plt.show()

# %%
plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['FSA'],label='moss_test1')
plt.plot(ALP1_moss2['FSA'],label='moss_test2')
plt.plot(ALP1_moss4['FSA'],label='moss_test4')
plt.plot(ALP1_moss5['FSA'],label='moss_test5')
plt.plot(ALP1_moss6['FSA'],label='moss_test6')
plt.plot(ALP1_moss7['FSA'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("FSA (W/m^2)")
plt.title("absorbed solar radiation")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_FSA.png")
plt.show()

# %%
plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['TSOI_10CM'],label='moss_test1')
plt.plot(ALP1_moss2['TSOI_10CM'],label='moss_test2')
plt.plot(ALP1_moss4['TSOI_10CM'],label='moss_test4')
plt.plot(ALP1_moss5['TSOI_10CM'],label='moss_test5')
plt.plot(ALP1_moss6['TSOI_10CM'],label='moss_test6')
plt.plot(ALP1_moss7['TSOI_10CM'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("TSOI_10CM (W/m^2)")
plt.title("soil temperature in top 10cm of soil")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_FSA.png")
plt.show()

# %%
plt.figure(figsize=(8,8))
#plt.plot(ALP1_lichen['SABG'],label='lichen')
#plt.plot(ALP1_lichen1['SABG'],label='lichen')
#plt.plot(ALP1_lichen2['SABG'],label='lichen')
plt.plot(ALP1_moss1['ED_biomass'],label='moss_test1')
plt.plot(ALP1_moss2['ED_biomass'],label='moss_test2')
plt.plot(ALP1_moss4['ED_biomass'],label='moss_test4')
plt.plot(ALP1_moss8['ED_biomass'],label='moss_test5')
plt.plot(ALP1_moss6['ED_biomass'],label='moss_test6')
plt.plot(ALP1_moss7['ED_biomass'],label='moss_test7')

plt.xlabel("time (months)")
plt.ylabel("ED_BIOMASS (gC m-2)")
plt.title("Total biomass")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_ED_BIOMASS.png")
plt.show()

# %%
ALP1_grass_hourly = xr.open_dataset('~/saga/work/ctsm/ALP1_grass/run/ALP1_grass.clm2.h1.2000-07-15-00000.nc')#alp1
ALP1_lichen_hourly = xr.open_dataset('~/saga/work/ctsm/ALP1_lichen/run/ALP1_lichen.clm2.h1.2000-07-15-00000.nc')#alp1
ALP1_moss_hourly = xr.open_dataset('~/saga/work/ctsm/ALP1_moss/run/ALP1_moss.clm2.h1.2000-07-15-00000.nc')#alp1

# %%
plt.figure(figsize=(8,8))
plt.plot(ALP1_grass_hourly['TSOI_10CM'],label='grass')
plt.plot(ALP1_lichen_hourly['TSOI_10CM'],label='lichen')
plt.plot(ALP1_moss_hourly['TSOI_10CM'],label='moss')
plt.xlabel("time (months)")
plt.ylabel("Temperature (K)")
plt.title("Monthly meant temperature")
plt.legend(loc='best')
plt.grid(True)
plt.savefig("/home/huitang/SynologyDrive/moss_lichen/sites_observation/monthly_temperature_3types.png")
plt.show()
